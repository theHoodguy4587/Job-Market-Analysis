# %%
import pandas as pd

df=pd.read_csv("../data/preprocessed/wwr_jobs_cleaned.csv")
df
# Out:
#                                              job_title  \
# 0                               online english teacher
# 1                                      managing editor
# 2               full-stack engineer python/react/genai
# 3                                     freelance writer
# 4                          embedded firmware developer
# ..                                                 ...
# 242               senior account executive saas remote
# 243           business development representative saas
# 244  managing director - fpa saas - private equity ...
# 245                             technical project lead
# 246  senior independent product manager/product des...
#
#                      company                location  \
# 0                native camp                   japan
# 1               the swiftest           san francisco
# 2                     toptal                  remote
# 3             prowritersites                new york
# ...
